# %% [markdown]
# <h1>Experiment 1 </h1>

# %%
# imports
import os

# %%
#creating and deleting file

with open("..//files//hello.txt","w") as f:
    f.write("Nameste Duiniya\nWelcome to the world of programming")

os.remove("../files/hello.txt")

# %%
#to find smaller, greator and equal btw two number

a = float(input("Enter a number-"))
b=float(input("Enter Second number-"))
if (a-b>0):
    print("First number is grator than second.")
elif (a-b<0):
    print("Second number is greator than first.")
else:
    print("Both the numbers are equal.")

# %%
#Diggerence btw division, floor division and modulous
a=5
b=2
c= 5/2
d=5//2
e=5%2
print(f"Quotient 1 = {c}\nQuotient 2 = {d}\nRemainder = {e}")

# %%
#To find wether odd or even
a = int(input("Enter a number:"))
if a%2==0:
    print("The given number is even.")
else:
    print("The given number is odd.")
